# %%
import pandas as pd

from sklearn import datasets
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import pickle
import joblib

from sklearn import linear_model
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
def carat_to_bins(df, carat):
    
    df.loc[df[carat].between(0, .5, 'left'), 'bin'] = 1.0
    df.loc[df[carat].between(.5, 1.0, 'left'), 'bin'] = 1.44
    df.loc[df[carat].between(1.0, 1.5, 'left'), 'bin'] = 2.3
    df.loc[df[carat].between(1.5, 2.0, 'left'), 'bin'] = 3.21
    df.loc[df[carat].between(2.0, 3.0, 'left'), 'bin'] = 4.12
    df.loc[df[carat].between(3.0, 4.0, 'left'), 'bin'] = 5.53
    df.loc[df[carat].between(4.0, 10.0, 'left'), 'bin'] = 8.39
    
    return df

# %%
#scale

def scaling_feat(df, to_scale, not_to_scale, scale=1):
    
    scalable = df[to_scale]
    not_scalable = df[not_to_scale]

    if scale == 2:
        scaler = StandardScaler()
    elif scale ==3:
        scaler = RobustScaler()
    else:
        scaler = MinMaxScaler()

    scaled = pd.DataFrame(scaler.fit_transform(scalable), columns=to_scale)
    
    return not_scalable.join(scaled)

# %%
df = pd.read_csv('../data/diamonds_train.csv')
pre_x_test = pd.read_csv('../data/diamonds_test.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
pre_x_test.drop(columns=['id'], inplace=True)

# %%
zeros = df[df['z'] == 0].index

# %%
df.drop(labels=zeros, axis=0, inplace=True)

# %%
#columns bin for carat

df = carat_to_bins(df, 'carat')

# %%
def classify_diamond_shape(x, y, z):
    # Calculate ratios
    length_to_width_ratio = x / y
    length_to_depth_ratio = x / z

    # Define shape classification ranges
    shape_ranges = {
        'Round Brilliant': {
            'length_to_width_ratio': (0.95, 1.05),
            'length_to_depth_ratio': (1.35, 1.75)
        },
        'Princess': {
            'length_to_width_ratio': (0.90, 1.10),
            'length_to_depth_ratio': (0.90, 1.10)
        },
        'Emerald': {
            'length_to_width_ratio': (1.20, 1.60),
            'length_to_depth_ratio': (1.30, 1.60)
        },
        'Radiant': {
            'length_to_width_ratio': (1.00, 1.30),
            'length_to_depth_ratio': (1.00, 1.30)
        },
        'Pear': {
            'length_to_width_ratio': (1.40, 2.00),
            'length_to_depth_ratio': (1.30, 1.70)
        },
        'Marquise': {
            'length_to_width_ratio': (1.60, 2.10),
            'length_to_depth_ratio': (1.30, 2.20)
        },
        'Oval': {
            'length_to_width_ratio': (1.20, 1.70),
            'length_to_depth_ratio': (1.30, 1.70)
        }
    }

    # Classify the diamond shape
    for shape, ranges in shape_ranges.items():
        if (ranges['length_to_width_ratio'][0] <= length_to_width_ratio <= ranges['length_to_width_ratio'][1]
                and ranges['length_to_depth_ratio'][0] <= length_to_depth_ratio <= ranges['length_to_depth_ratio'][1]):
            return shape

    return 'Unknown'  # If no shape match is found

# %%
shapes = []

for i in range(len(df)):
    x = df['x'].iloc[i]
    y = df['y'].iloc[i]
    z = df['z'].iloc[i]

    shapes.append(classify_diamond_shape(x, y, z))
    
shapes
# Out:
# ['Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Unknown',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Unknown',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Unknown',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Unknown',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Unknown',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  'Round Brilliant',
#  ...]

# %%
shapes_df = pd.DataFrame(shapes, columns=['shape'])

# %%
unk = shapes_df[shapes_df['shape'] == 'Unknown'].index

# %%
shapes_df['shape'].value_counts()
# Out:
# Round Brilliant    40223
# Unknown              211
# Radiant                3
# Princess               1
# Marquise               1
# Name: shape, dtype: int64

# %%
df.iloc[unk].loc[df['xy']<1.050]
# Out:
#        carat      cut color clarity  depth  table     x     y     z  \
# 10      1.02  Premium     I     SI1   58.0   58.0  6.84  6.60  3.90
# 41      1.00     Fair     H     SI1   55.2   64.0  6.69  6.64  3.68
# 164     0.88     Fair     F     SI1   56.6   65.0  6.39  6.32  3.60
# 928     0.99     Fair     J     SI1   55.0   61.0  6.72  6.67  3.68
# 956     1.50     Good     G      I1   57.4   62.0  7.56  7.39  4.29
# ...      ...      ...   ...     ...    ...    ...   ...   ...   ...
# 39874   1.00  Premium     F     VS1   59.2   60.0  6.53  6.48  3.58
# 40145   0.38     Good     F     VS2   56.2   61.0  4.84  4.87  2.73
# 40202   0.39     Good     F    VVS2   57.7   61.0  4.91  4.80  2.80
# 40270   2.02     Good     F     SI2   57.1   60.0  8.31  8.25  4.73
# 40307   0.84     Fair     G     SI1   55.1   67.0  6.39  6.20  3.47
#
#                 city  price   bin        xy        xz
# 10          Tel Aviv   4284  2.30  1.036364  1.753846
# 41     New York City   3830  2.30  1.007530  1.817935
# 164           Madrid   2882  1.44  1.011076  1.775000
# 928            Dubai   2812  1.44  1.007496  1.826087
# 956         Kimberly   3179  3.21  1.023004  1.762238
# ...              ...    ...   ...       ...       ...
# 39874          Dubai   7056  2.30  1.007716  1.824022
# 40145       Tel Aviv    873  1.00  0.993840  1.772894
# 40202      Las Vegas   1058  1.00  1.022917  1.753571
# 40270         Madrid  12615  4.12  1.007273  1.756871
# 40307     Luxembourg   2782  1.44  1.030645  1.841499
#
# [195 rows x 14 columns]

# %%
df['xy'] = df['x'] / df['y']
df['xz'] = df['x'] / df['z']

# %%
df['xy'].max()
# Out:
# 1.6155717761557176

# %%
df['xz'].max()
# Out:
# 6.186915887850467

# %%
df[df['xz'] > 2]
# Out:
#        carat        cut color clarity  depth  table     x     y     z  \
# 7956    0.55  Very Good     E     VS2   61.0   59.0  5.31  5.34  2.25
# 7967    1.07      Ideal     F     SI1   60.6   57.0  6.62  6.67  1.07
# 12924   1.53      Ideal     I     SI1   61.9   54.0  7.43  7.50  1.53
# 16544   1.57       Fair     H     VS1   67.3   66.0  7.85  5.75  3.87
# 20014   0.38      Ideal     E    VVS2   60.9   56.0  4.71  4.68  2.06
# 35619   0.34       Good     E     VS2   57.0   61.0  6.65  4.61  2.64
#
#              city  price   bin        xy        xz
# 7956   Luxembourg   1831  1.44  0.994382  2.360000
# 7967       London   5909  2.30  0.992504  6.186916
# 12924   Las Vegas   8971  3.21  0.990667  4.856209
# 16544     Antwerp   8133  3.21  1.365217  2.028424
# 20014  Luxembourg   1068  1.00  1.006410  2.286408
# 35619      Zurich    816  1.00  1.442516  2.518939

# %%
xx = pre_x_test.groupby(['carat', 'cut', 'color', 'clarity']).sum().reset_index()[['carat', 'cut', 'color', 'clarity']]
# Out:
# C:\Users\magno.MAUDITORS\AppData\Local\Temp\ipykernel_16016\497798654.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   xx = pre_x_test.groupby(['carat', 'cut', 'color', 'clarity']).sum().reset_index()[['carat', 'cut', 'color', 'clarity']]

# %%
yy = df.groupby(['carat', 'cut', 'color', 'clarity']).sum().reset_index()[['carat', 'cut', 'color', 'clarity']]
# Out:
# C:\Users\magno.MAUDITORS\AppData\Local\Temp\ipykernel_16016\2927866094.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yy = df.groupby(['carat', 'cut', 'color', 'clarity']).sum().reset_index()[['carat', 'cut', 'color', 'clarity']]

# %%
xx['concat'] = str(xx['carat']) + xx['cut'] + xx['color'] + xx['clarity']

# %%
xx
# Out:
#       carat        cut color clarity  \
# 0      0.20      Ideal     E     VS2
# 1      0.20    Premium     D     VS2
# 2      0.20    Premium     E     VS2
# 3      0.20    Premium     F     VS2
# 4      0.20  Very Good     E     VS2
# ...     ...        ...   ...     ...
# 6871   3.01    Premium     J     SI2
# 6872   3.04  Very Good     I     SI2
# 6873   3.65       Fair     H      I1
# 6874   3.67    Premium     I      I1
# 6875   5.01       Fair     J      I1
#
#                                                  concat
# 0     0       0.20\n1       0.20\n2       0.20\n3   ...
# 1     0       0.20\n1       0.20\n2       0.20\n3   ...
# 2     0       0.20\n1       0.20\n2       0.20\n3   ...
# 3     0       0.20\n1       0.20\n2       0.20\n3   ...
# 4     0       0.20\n1       0.20\n2       0.20\n3   ...
# ...                                                 ...
# 6871  0       0.20\n1       0.20\n2       0.20\n3   ...
# 6872  0       0.20\n1       0.20\n2       0.20\n3   ...
# 6873  0       0.20\n1       0.20\n2       0.20\n3   ...
# 6874  0       0.20\n1       0.20\n2       0.20\n3   ...
# 6875  0       0.20\n1       0.20\n2       0.20\n3   ...
#
# [6876 rows x 5 columns]

# %%
final = pd.read_csv('../data/prices_013.csv', sep=';')

# %%
final.reset_index(drop=True, inplace=True)

# %%
final = final.set_index('id')

# %%
final.to_csv('../data/prices_014.csv')

# %%
final
# Out:
#        price
# id
# 0       3165
# 1       5287
# 2       9585
# 3       4001
# 4       1657
# ...      ...
# 13480   1716
# 13481   2290
# 13482   3109
# 13483   1997
# 13484    908
#
# [13485 rows x 1 columns]
